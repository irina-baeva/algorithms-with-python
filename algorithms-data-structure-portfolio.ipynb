# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Asymptotic notations
#
# >**Algorithm** - is a set of steps to accomplish the task (c) Khan Academy
#
# What makes good algorithm:
#
# •	Correctness
#
# •	Efficiency - is how well you are using your computer’s resources to get a particular job done.
#
# *Complexity* – is a measure of algorithm efficiency in terms of time usage.
# Ways to approach the task:
#
# - Divide-and-concuer
# - Gready method - the algorithm checks the problem one step at the time and focuses just on this step (often as a part of optimisation)
#
# *Asymptotic notations* are the mathematical notations used to describe the running time of algorithms when the input tends towards a particular value or a limiting value. It helps to make comparison between different algorithms, especially on large inputs.
# <br> High level idea: to suppress constant factors (like system dependency) and lower terms (irrelevant for large inputs). So we simplify function in order to drop the less significant parts.
# <br> For example, if the function: $ an^2*bn+c $, we can say that our algorithm takes $ n^2 $, so we are dropping:
# <br> 1) coefficient because it does not matter what coefficient used,
# <br> 2) last part bn+c because it is relatively small compare to first part $ n^2 $
#
# Also it doesn't matter what base of the logarithm we use in asymptotic notation.
#
# There are three main types of asymptotic notations:
# 	- big-O (worst case)
# 	- big-Θ or big-Theta (average case)
# 	- big-Ω or big–Omega (best case)
# ### Let’s explore different complexity of big-O:
# <br>**Constant complexity O(1)** – the same time no matter how big input.
# Example:

# %%
def sum(a, b, c):
    return a + b + c
sum(3, 2, 1)
# takes the same time as:
sum(1000, 300, 111)
# Out:
# 1411

# %%
x = [3, 2, 1, 8, 300, 111] #input(n)
y = [5, 5, 5, 5, 5, 5] #number or iterations

plt.plot(x, y, 'g')
plt.title('Constant Complexity O(n)')
plt.xlabel('Inputs')
plt.ylabel('Iterations')
plt.show()

# %% [markdown]
# **Linear complexity O(n)** – the number of operations grows in the same rate as number of inputs.
# Example (linear search):

# %%
foodArray = ['pizza', 'burger', 'sushi', 'curry']
def findFoodInTheApp(arrayOfFood, desiredFood):
    for food in arrayOfFood:
        if food == desiredFood:
            return f'Here is your {food}'
print(findFoodInTheApp(foodArray, 'curry')) #To find a "curry" is taking O(n)
# Out:
# Here is your curry

# %%
x = [3, 2, 1, 8, 300, 111] #inputs(n)
y = [3, 2, 1, 8, 300, 111] #number or iterations

plt.plot(x, y, 'g')
plt.xlabel('Inputs')
plt.ylabel('Iterations')
plt.title('Linear Complexity O(n)')
plt.show()

# %% [markdown]
# **Logarithmmic complexity O(log n)** – the number of operation grows slower than the inputs. More efficient for larger inputs. Example: binary search.

# %%
x = [1, 4, 8, 16, 64, 1024, 2048, 4096, 8192, 16384] #inputs grow faster
y = [1, 2, 3, 4, 6, 10, 11, 12, 13, 14] #number or iterations

plt.plot( x, y, 'g')
plt.xlabel('Inputs')
plt.ylabel('Iterations')
plt.title('Logarithmmic Complexity O(log n)')
plt.show()

# %% [markdown]
# **Linearithmic complexity O(n*log(n))** - slower then linear, but better then quadratic.  Examples (merge sort, quick sort)

# %%
x = [1, 4, 8, 16, 64, 1024, 2048, 4096, 8192, 16384] #input(n)
y = [1, 4*2, 8*3, 16*4, 64*6, 1024*10, 2048*11, 4096*12, 8192*13, 16384*14] #number or iterations

plt.plot( x, y, 'g')
plt.xlabel('Inputs')
plt.ylabel('Iterations')
plt.title('Linearithmic  Complexity O(n*log n)')
plt.show()

# %% [markdown]
# **Quadratic complexity O(n^2)** - operations grow as a square of the number of inputs. When we have nested iterations. Ex. bubble sort, selection sort, insertion sort

# %%
x = [1, 4, 8, 16, 64, 1024, 2048, 4096] #input(n)

y = [1, 16, 64, 256, 4096, 1048576, 4194304, 16777216] #number or iterations

plt.plot(x, y, 'g')
plt.xlabel('Inputs')
plt.ylabel('Iterations')
plt.title('Quadratic complexity O(n2)')
plt.show()

# %% [markdown]
# **Exponential complexity O(2n)** The algorithm takes twice the number of previous operations for every new element added. Example: recursive calculation of Fibonacci numbers.

# %% [markdown]
# **Factorial complexity O(n!)** – very slow. Ex. traveling salesman

# %%
x = [1, 2, 3, 4, 5, 8, 10 ] #input(n)

y = [1, 2, 6, 24, 120, 40320, 3628800 ] #number or iterations

plt.plot(x, y, 'g')
plt.xlabel('Inputs')
plt.ylabel('Iterations')
plt.title('Factorial complexity O(n!)')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Recursion

# %% [markdown]
# ### Description
# **Recursion** is a method of solving problems that relies on the capability of a function to continue calling itself until it satisfies a particular condition.
# >“Recursion is when function calls itself until it doesn't” 🙈 by Fun Fun Functions
#
# Recursion function consists of two main points:
# 1.	Base case (exit condition, otherwise infinite loop)
# 2.	The rule how to move through function (alter input parameter)
#
# Recursion is similar to while loop, because we also keep going through some piece of code again and again till exit or break condition (when we need to stop).
#
# ### Example:
#
# Find n!:
# <br>Base case: If n = 0, then n! = 1
# <br>The rule: If n > 0, then n! = n*(n-1)!
# <br> So factorial of 3 or 3! is

# %%
def factorial(n):
    if n == 0: #base case or when we need to stop
        return 1
    else:
        return n * factorial(n - 1) #how to move
 
factorial_3 = factorial(3)
print(factorial_3) #6
# Out:
# 6

# %% [markdown]
# Steps:
# 1. $factorial(3)$
# 2. $ 3* factorial(2)$
# 3. $ 3*2*factorial(1)$
# 4. $3*2*1$
# 5. $6$
#
# We can see step by step logic of recursive function. We are not multiplying till we dig dipper and hit base case - factorial(1), then we move forward and multiply.

# %% [markdown]
# ---

# %% [markdown]
# ## Binary Search
#
# ### Description
#
# The goal of **Binary search**  is finding an item from a sorted list of items. It works by repeatedly dividing in half the length of the list that could contain the item, until it has narrowed down the possible locations to just one.(c) <a src="https://www.khanacademy.org/computing/computer-science/algorithms/binary-search/a/binary-search![image.png](attachment:image.png)">Khan Academy</a>
#
# ### Example
# <div>
# <img src="attachment:Picture%201.png" width="500"/>
# </div>
# In the example above we are searching for number 40. In the end we compare the number to 32 and the last one 33. Then we can conclude that there is no such a number in the current sorted array.
#
#
#
# ### Time complexity
# Efficiency is not going to be as big as Linear O(n). Let’s consider how many iterations we have with different sizes of array (assumption from Udacity example).
# <div> <img src="attachment:binary_search.png" width="500"/></div>
#
# Logarithms are the inverse of exponentials, so that if log(n)=x then n = 2^x. We can see patterns and logic behind of the examples, it follows as that efficiency of the binary search could be:
#
# $O(log(n)+1$
#
# From above explanation of asymptotic notation, we can conclude that adding one does not change efficiency much, so we get
#
# <center><font color='darkgreen'> $O(log(n)$ </font></center>
# Best case of binary search is <font color='darkgreen'> $ O(1) $ </font> (when searched element in the middle position)
#
# The logarithm function grows very slowly. So O(log n) is faster than O(n), but it gets a lot faster as the list of items grows.
#
#  | Worse case | Average case | Best case
# --- | --- | ---
#  | $O(log(n)$ | $O(log(n)$ | O(1)
#
# ### Code example

# %% [markdown]
# [binary_search.py](algorithms/searching/binary_search.py)

# %%
- [ ]  Goal of the algorithm
- [ ]  Termination condition
- [ ]  Criteria for determining that the algorithm is correct
- [ ]  Explanation of the steps of the algorithm

# %%
## Binary Search

### Description

### Example 

### Time complexity

### Code example
